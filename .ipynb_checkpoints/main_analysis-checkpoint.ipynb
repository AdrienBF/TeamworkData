# %% [markdown]
# # Analysis of the data
# In this section, we present our results. First, we download our data:

# %%
from download import download_all
from req import RequestHelper
req = RequestHelper(disable_debug_print=True)

# %%
# By instantiating the RequestHelper in the previous cell and passing it here, 
# we enable caching of hte requests. Therefore, if we want to run this cell again
# with higher number of calls, we do not make the same call again.
# Try this with running this cell for the first time (takes time to evaulate),
# where the second run (for the same batch size) is almost instant.
data = download_all(count_of_eshops=100, req=req)
# Out:
#  - getting Heureka lists of eshops:
# 100%|██████████| 6/6 [00:11<00:00,  1.90s/it]
#  - getting Heureka page details:
# 100%|██████████| 100/100 [00:52<00:00,  1.88it/s]
# Data from Heureka finished in 63.581s.
#  - getting data from eshop pages in 30 threads:
# 100%|██████████| 100/100 [00:06<00:00, 16.37it/s]
# Data from Eshop pages finished in 6.167s.
#  - getting data from Instagram:
# 100%|██████████| 36/36 [00:17<00:00,  2.00it/s]
# Data from Instagram pages finished in 17.715s.

# %% [markdown]
# We inspect the data:

# %%
data.head()
# Out:
#                                                                 inner_link  \
# link
# https://www.notino.cz/   https://obchody.heureka.cz/notino-cz/recenze/o...
# http://www.megaknihy.cz  https://obchody.heureka.cz/megaknihy-cz/recenz...
# http://www.eva.cz        https://obchody.heureka.cz/eva-cz/recenze/overene
# http://www.lekarna.cz/   https://obchody.heureka.cz/lekarna-cz/recenze/...
# http://www.astratex.cz   https://obchody.heureka.cz/astratex-cz/recenze...
#
#                                  name  rating   reviews  \
# link
# https://www.notino.cz/         Notino     4.8  114679.0
# http://www.megaknihy.cz  MegaKnihy.cz     4.8   68460.0
# http://www.eva.cz              EVA.cz     4.8   64442.0
# http://www.lekarna.cz/     Lékárna.cz     4.8   53111.0
# http://www.astratex.cz    Astratex.cz     4.8   51268.0
#
#                          reviews_negative_count  reviews_positive_count  \
# link
# https://www.notino.cz/                   1461.0                 91469.0
# http://www.megaknihy.cz                  5431.0                 62810.0
# http://www.eva.cz                        1614.0                 62523.0
# http://www.lekarna.cz/                   1422.0                 51426.0
# http://www.astratex.cz                   1087.0                 50007.0
#
#                            instagram  \
# link
# https://www.notino.cz/     notino_cz
# http://www.megaknihy.cz          NaN
# http://www.eva.cz                NaN
# http://www.lekarna.cz/    lekarna_cz
# http://www.astratex.cz   astratex.cz
#
#                                          instagram_classified_descriptions  \
# link
# https://www.notino.cz/     phone;1 person, closeup;1 person, closeup;shoes
# http://www.megaknihy.cz                                                NaN
# http://www.eva.cz                                                      NaN
# http://www.lekarna.cz/   1 person;1 person;tree, plant and outdoor;food...
# http://www.astratex.cz   one or more people;2 people;one or more people...
#
#                          instagram_followers  \
# link
# https://www.notino.cz/               32610.0
# http://www.megaknihy.cz                  NaN
# http://www.eva.cz                        NaN
# http://www.lekarna.cz/                2822.0
# http://www.astratex.cz                5005.0
#
#                                                        instagram_full_json  \
# link
# https://www.notino.cz/   {'biography': 'Na jaro musíš být fresh! 🌺 Vybe...
# http://www.megaknihy.cz                                                NaN
# http://www.eva.cz                                                      NaN
# http://www.lekarna.cz/   {'biography': 'Pro zdraví a krásu celé rodiny ...
# http://www.astratex.cz   {'biography': 'E-shop s největším výběrem spod...
#
#                          instagram_posts_average_like  instagram_posts_count
# link
# https://www.notino.cz/                     147.166667                 2037.0
# http://www.megaknihy.cz                           NaN                    NaN
# http://www.eva.cz                                 NaN                    NaN
# http://www.lekarna.cz/                      44.500000                  297.0
# http://www.astratex.cz                     107.916667                  714.0

# %%
data['reviews_positive_ratio'] = data['reviews_positive_count']/data['reviews']

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statistics as st
plt.style.use('ggplot')

# %%
data.corr().style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_485a083a_7c00_11e9_b30b_002315d16290row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col3 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col5 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row0_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col2 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col3 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col4 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col5 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col6 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row1_col7 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col1 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col3 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col5 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col6 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row2_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col2 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col4 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row3_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col0 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col1 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col3 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col5 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col6 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row4_col7 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col0 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col6 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row5_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col0 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col1 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col3 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col4 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col5 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row6_col7 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row7_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row7_col1 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row7_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_485a083a_7c00_11e9_b30b_002315d16290row7_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;

# %%
sns.pairplot(data)
# pairplot issues a warning about non-numeric data which can be safely ignored
plt.show()
# Out:
# C:\Users\matej\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\matej\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Now we try to plot the _reviews_ vs _instagram_\__followers_

# %%
f, ax = plt.subplots(num=None, figsize=(15, 7))
data.plot.scatter('reviews', 'instagram_followers', ax=ax,)
plt.show()

# %% [markdown]
# There is, however, not much to see. Can we improve it by log-scaling?

# %%
f, ax = plt.subplots(num=None, figsize=(15, 7))
data.plot.scatter('reviews', 'instagram_followers', ax=ax,)
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %% [markdown]
# Nevertheless, there appears to be no stable relationship. Now what about the correlations?

# %%
sub_data = data[['reviews', 'instagram_followers']].dropna()
sub_data['log(reviews)'] = np.log(data['reviews'])
sub_data['log(instagram_followers)'] = np.log(data['instagram_followers'])
sub_data.corr().style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col1 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col2 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col0 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col3 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col0 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col0 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col1 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col2 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_5359fc36_7c00_11e9_b3c5_002315d16290" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reviews</th>        <th class="col_heading level0 col1" >instagram_followers</th>        <th class="col_heading level0 col2" >log(reviews)</th>        <th class="col_heading level0 col3" >log(instagram_followers)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5359fc36_7c00_11e9_b3c5_002315d16290level0_row0" class="row_heading level0 row0" >reviews</th>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col1" class="data row0 col1" >0.360338</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col2" class="data row0 col2" >0.910363</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row0_col3" class="data row0 col3" >0.295467</td>
#             </tr>
#             <tr>
#                         <th id="T_5359fc36_7c00_11e9_b3c5_002315d16290level0_row1" class="row_heading level0 row1" >instagram_followers</th>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col0" class="data row1 col0" >0.360338</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col2" class="data row1 col2" >0.139317</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row1_col3" class="data row1 col3" >0.810371</td>
#             </tr>
#             <tr>
#                         <th id="T_5359fc36_7c00_11e9_b3c5_002315d16290level0_row2" class="row_heading level0 row2" >log(reviews)</th>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col0" class="data row2 col0" >0.910363</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col1" class="data row2 col1" >0.139317</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row2_col3" class="data row2 col3" >0.189473</td>
#             </tr>
#             <tr>
#                         <th id="T_5359fc36_7c00_11e9_b3c5_002315d16290level0_row3" class="row_heading level0 row3" >log(instagram_followers)</th>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col0" class="data row3 col0" >0.295467</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col1" class="data row3 col1" >0.810371</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col2" class="data row3 col2" >0.189473</td>
#                         <td id="T_5359fc36_7c00_11e9_b3c5_002315d16290row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# From 5.4% for the non-transformed scenario we cannot do better than 18% for _reviews_ vs _log(instagram_\__followers)_.
#
# We can also try other variables:

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
data.plot.scatter('reviews', 'instagram_posts_average_like', ax=ax,)
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
data.plot.scatter('reviews_positive_ratio', 'instagram_posts_average_like', ax=ax,)
ax.set_yscale('log')
plt.show()

# %% [markdown]
# However, the story is similar, there is no clear pattern in the data.

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
data.plot.scatter('reviews', 'instagram_posts_count', ax=ax,)

plt.show()

# %% [markdown]
# Except for the three outliers in the top-left corner, it seems that the more you post, the more you are wellknown on Heureka.

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
data.plot.scatter('reviews_positive_ratio', 'instagram_followers', ax=ax,)

plt.show()

# %% [markdown]
# Based on the down-right corner, there is just a slightly positive correlation between fame on instagram and positiveness of the reviews. We can see that the most well-known firms have a worse positive-ratio.
#
# Is there any difference between firms with or without instagram?

# %%
data['hasinsta'] = data['instagram'].notnull()
data['hasinsta'] = data['hasinsta']*1
dt1 = data[data.hasinsta != 0].copy() # Firms with an instagram account
dt0 = data[data.hasinsta != 1].copy() # Firms without an instagram account

# %%
print('Average of reviews positive ratio for firms with an instagram account:')
np.mean(dt1['reviews_positive_ratio'])
# Out:
# Average of reviews positive ratio for firms with an instagram account:
# 0.8994972834535305

# %%
print('Average of reviews positive ratio for firms without an instagram account:')
np.mean(dt0['reviews_positive_ratio'])
# Out:
# Average of reviews positive ratio for firms without an instagram account:
# 0.9312632198934653

# %% [markdown]
# There is a little evidence that not being present on instagram helps a firm to have better reviews.
#
# But maybe being on instagram helps firms to get more reviews ?

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
bins = np.linspace(-50, 70000, 50)
ax.hist(dt1['reviews'], bins, alpha=0.5, label='instagram account')
ax.hist(dt0['reviews'], bins, alpha=0.5, label='no instagram account')
ax.legend(loc='upper right')
ax.set_ylabel('frequency')
ax.set_xlabel('reviews')
plt.show()

# %% [markdown]
# The center of the plot is more favorable to firms with instagram, and low numbers of reviews are saturated by firms without instagram. The interpretation is not clear due to the 2 values between 60000 and 70000. Nonetheless, if we consider them as outliers, we can say that instagram helps having more reviews (or firm with a lot of reviews are more inclined to have an instagram account...).

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
bins = np.linspace(0.4, 1, 50)
ax.hist(dt1['reviews_positive_ratio'], bins, alpha=0.5, label='instagram account')
ax.hist(dt0['reviews_positive_ratio'], bins, alpha=0.5, label='no instagram account')
ax.legend(loc='upper left')
ax.set_ylabel('frequency')
ax.set_xlabel('reviews_positive_ratio')
plt.show()

# %% [markdown]
# With this plot showing that worst grades are mainly for firms present on instagram, we can be pretty sure that big firms, despite having an instagram account, face lower grades.
#
# Now, we can try to separate the data between active or non-active firms on instagram (i.e. high number of posts) to see if instagram is usefull to them.

# %%
st.median(dt1['instagram_posts_count'])
# Out:
# 351.5

# %%
dt1['active'] = (dt1['instagram_posts_count'] >= 349) * 1
act1 = dt1[dt1.active != 0] # Active firms
act0 = dt1[dt1.active != 1] # Non active firms

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
bins = np.linspace(0.4, 1, 50)
ax.hist(act1['reviews_positive_ratio'], bins, alpha=0.5, label='Active firms')
ax.hist(act0['reviews_positive_ratio'], bins, alpha=0.5, label='Non active firms')
ax.legend(loc='upper left')
ax.set_ylabel('frequency')
ax.set_xlabel('reviews_positive_ratio')
plt.show()

# %% [markdown]
# Being active on instagram helps having better reviews.

# %%
f, ax = plt.subplots(num=2, figsize=(15, 7))
act1.plot.scatter('reviews', 'instagram_followers', ax=ax, label='Active firms', c='red')
act0.plot.scatter('reviews', 'instagram_followers', ax=ax, label='Non active firms')
plt.show()

# %% [markdown]
# To sum it up, firms highly active on instagram seem to have more followers but not necessarily more reviews.
